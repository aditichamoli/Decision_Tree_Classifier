# %% [markdown]
# <h1>Objective: Creating a Decision Tree classifier and visualizing it graphically.</h1>

# %% [markdown]
# <h2>Author: Aditi Chamoli</h2>

# %% [markdown]
# <h1>Prediction using Decision Tree Algorithm</h1>

# %% [markdown]
# <h1>Importing libraries</h1>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import sklearn.tree as tree

# %% [markdown]
# <h1>Importing dataset</h1>

# %%
iris_data=pd.read_csv("Iris.csv")
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# <h1>Splitting the data into testing and training data for model building</h1>

# %%
X=iris_data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
Y=iris_data['Species']
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# <h1>Fitting the data into DecisionTree Classifier model</h1>

# %%
decision_tree=DecisionTreeClassifier(max_leaf_nodes=10,random_state=0)
decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10, random_state=0)

# %% [markdown]
# <h1>Visualizing the Decision Tree</h1>

# %%
dot_data = tree.export_graphviz(decision_tree, out_file=None, 
                         feature_names=X.columns,  
                         class_names=["Iris-virginica","Iris-setosa","Iris-Versicolor"],  
                         filled=True, rounded=True,  
                         special_characters=True,proportion=True)

# %%
import pydotplus
graph = pydotplus.graph_from_dot_data(dot_data)
from IPython.display import Image
Image(graph.create_png())

# %% [markdown]
# <h1>Performing predictions</h1>

# %%
y_prediction = decision_tree.predict(x_test)

# %% [markdown]
# <h1>Comparing actual values vs predicted values</h1>

# %%
df= pd.DataFrame({'Actual':y_test,'Predicted':y_prediction})
df
# Out:
#               Actual        Predicted
# 114   Iris-virginica   Iris-virginica
# 62   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 107   Iris-virginica   Iris-virginica
# 7        Iris-setosa      Iris-setosa
# 100   Iris-virginica   Iris-virginica
# 40       Iris-setosa      Iris-setosa
# 86   Iris-versicolor  Iris-versicolor
# 76   Iris-versicolor  Iris-versicolor
# 71   Iris-versicolor  Iris-versicolor
# 134   Iris-virginica   Iris-virginica
# 51   Iris-versicolor  Iris-versicolor
# 73   Iris-versicolor  Iris-versicolor
# 54   Iris-versicolor  Iris-versicolor
# 63   Iris-versicolor  Iris-versicolor
# 37       Iris-setosa      Iris-setosa
# 78   Iris-versicolor  Iris-versicolor
# 90   Iris-versicolor  Iris-versicolor
# 45       Iris-setosa      Iris-setosa
# 16       Iris-setosa      Iris-setosa
# 121   Iris-virginica   Iris-virginica
# 66   Iris-versicolor  Iris-versicolor
# 24       Iris-setosa      Iris-setosa
# 8        Iris-setosa      Iris-setosa
# ...

# %% [markdown]
# <h1> Measuring the accuracy of the DecisionTree Classifier </h1>

# %%
accuracy_score(y_true=y_test,y_pred=y_prediction)
# Out:
# 0.9736842105263158
